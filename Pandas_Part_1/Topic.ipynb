# %%
# First of all You must see that :

# 1. How big is your particular dataset.
# 2. What are the names of columns in your dataset.

# -> Shape and columns :

import pandas as pd

df = pd.read_csv('Data_sources&Data_sets/Employees_Info_dataset.csv')

df
# Out:
#       Name                                Job Type  Salary(Rs)  Age  \
# 0    Ahmad                            Data Analyst      500000   22
# 1    Tariq                          Data Scientist     1730000   23
# 2    Maria               Machine learning Enginear     1240000   24
# 3    Sofia                         Gen AI Engineer     2300000   23
# 4    Zenat  Agentic  AI and Deep learning Engineer     2700000   25
# 5    Rehan                       Software Engineer      890000   24
# 6   Faizan                      AI Product Manager    23000000   26
# 7     Saad                                      HR     1100000   28
# 8  Khadija                       Managing Director     1340000   29
# 9  Sameena                       Marketing Manager     1500000   27
#
#            Company                    Address Experience  Performance Points
# 0  Google Alphabet  Mountain View, California    1 years                  67
# ...

# %%
print(f"Shape of Dataset : {df.shape}")
# Out:
# Shape of Dataset : (10, 8)

# %%
print(f"Columns in dataset : {df.columns}")

# So these are the two very important datasets related Pandas attributes in Python library pandas.
# Out:
# Columns in dataset : Index(['Name', 'Job Type', 'Salary(Rs)', 'Age', 'Company', 'Address',
#        'Experience', 'Performance Points'],
#       dtype='str')

# %% [markdown]
# '''
# Select specific column in the dataset and then perform operations on this dataset.
# filter rows in the dataset based on conditions and that conditions aligned may be to any particular column in the dataset.
# conbime multiple conditions and perform filtering operations in dataset.
# '''
