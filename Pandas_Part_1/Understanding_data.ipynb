# %%
# Understanding the dataset :

'''
First we need to understand these things :

1. Number of rows and columns in a dataset.
2. Which type of Data either numerical(integer or float) or qualitative(string) have stored in rows or records of particular column of dataset.
3. Missing data in dataset like in which column's rows the data is missing and wich type of data of that particular column
   missing(column's rows datatype of that particular column data.
'''
import pandas as pd

df = pd.read_csv('Data_sources&Data_sets/Employees_data.csv')

df
# Out:
#      Name  Age                                                Job    Company
# 0   Ahmad   23  Senior Data Scientist and Machine Learning Expert     Google
# 1   Rehan   24                                    Product Manager  Microsoft
# 2  Faizan   22                                  Marketing Manager     Nvidia

# %%
Info_details = df.info()

print(Info_details)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      str
#  1   Age      3 non-null      int64
#  2   Job      3 non-null      str
#  3   Company  3 non-null      str
# dtypes: int64(1), str(3)
# memory usage: 228.0 bytes
# None

# %%
# like now we use this terminology on JSON file :

df2 = pd.read_json('Data_sources&Data_sets/sample_Data.json')
Info_JSON_details = df2.info()

df2
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   name         20 non-null     str
#  2   description  20 non-null     str
#  3   price        20 non-null     float64
#  4   category     20 non-null     str
#  5   image        20 non-null     str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 1.1 KB
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# ...
