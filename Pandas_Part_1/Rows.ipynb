# %%
# lets explore the functionality of rows in pandas :

# Now I use .head() to show first rows of dataset if cannot pass any n number other as on basis of my n number :
import pandas as pd

df = pd.read_csv('Data_sources&Data_sets/customer.csv')

df
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0       708082083            24      F                1      Uneducated
# 1       708083283            62      F                0         Unknown
# 2       708084558            32      F                1         Unknown
# 3       708085458            38      M                2      Uneducated
# 4       708086958            48      M                4        Graduate
# ...           ...           ...    ...              ...             ...
# 10103   827695683            44      M                3        Graduate
# 10104   827703258            48      M                3         Unknown
# 10105   827712108            47      M                4        Graduate
# 10106   827888433            42      F                3        Graduate
# 10107   827890758            47      M                4     High School
#
#       Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
df.head() # By default print first five rows if I caanot specify any n rows in function head()
# Out:
#    Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0   708082083            24      F                1      Uneducated
# 1   708083283            62      F                0         Unknown
# 2   708084558            32      F                1         Unknown
# 3   708085458            38      M                2      Uneducated
# 4   708086958            48      M                4        Graduate
#
#   Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# 0         Single       FL    91750        no         yes            no
# 1        Married       NJ    91750        no          no            no
# 2        Married       NJ    91750       yes          no            no
# 3         Single       NY    91750        no          no            no
# 4         Single       TX    91750       yes         yes            no
#
#     contact   Customer_Job  Income  Cust_Satisfaction_Score
# 0   unknown    Businessman  202326                        3
# ...

# %%
df.head(12) # Then in this situation its shows first 12 rows because n = 12
# Out:
#     Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0    708082083            24      F                1      Uneducated
# 1    708083283            62      F                0         Unknown
# 2    708084558            32      F                1         Unknown
# 3    708085458            38      M                2      Uneducated
# 4    708086958            48      M                4        Graduate
# 5    708095133            33      F                1     High School
# 6    708098133            34      F                3        Graduate
# 7    708099183            34      F                2      Uneducated
# 8    708100533            48      M                2     High School
# 9    708103608            53      F                1        Graduate
# 10   708104658            31      F                0   Post-Graduate
# 11   708108333            34      F                4        Graduate
#
# ...

# %%
df.tail()  # Same as like in tail.
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 10103   827695683            44      M                3        Graduate
# 10104   827703258            48      M                3         Unknown
# 10105   827712108            47      M                4        Graduate
# 10106   827888433            42      F                3        Graduate
# 10107   827890758            47      M                4     High School
#
#       Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# 10103         Single       NV    91750       yes         yes           yes
# 10104        Unknown       TX    91750        no         yes            no
# 10105        Married       NY    91750       yes          no            no
# 10106        Married       TX    91750        no          no            no
# 10107        Married       NY    91750        no         yes            no
#
#         contact   Customer_Job  Income  Cust_Satisfaction_Score
# ...

# %%
df.tail(13) # Same as in tail as like when I specify n = 13 means last 13 rows of dataset.
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 10095   827476983            54      F                0       Doctorate
# 10096   827619933            39      F                4         Unknown
# 10097   827628408            49      F                1      Uneducated
# 10098   827631483            52      F                3        Graduate
# 10099   827635083            39      M                2     High School
# 10100   827643858            44      F                2         Unknown
# 10101   827683383            42      F                3      Uneducated
# 10102   827691858            46      F                5        Graduate
# 10103   827695683            44      M                3        Graduate
# 10104   827703258            48      M                3         Unknown
# 10105   827712108            47      M                4        Graduate
# 10106   827888433            42      F                3        Graduate
# ...
