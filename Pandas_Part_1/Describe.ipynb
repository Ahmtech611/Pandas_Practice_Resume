# %%
# Describe method :
# First we create a dataset by using Python Dictionary :

import pandas as pd 

Data = {
    'Name' : ['Ahmad', 'Tariq', 'Maria', 'Sofia', 'Zenat',' Rehan', 'Faizan', 'Saad', 'Khadija', 'Sameena'],
    'Job Type' : ['Data Analyst', 'Data Scientist', 'Machine learning Enginear', 'Gen AI Engineer', 'Agentic  AI and Deep learning Engineer', 'Software Engineer', 'AI Product Manager', 'HR', 'Managing Director', 'Marketing Manager'],
    'Salary(Rs)' : [500000, 1730000, 1240000, 2300000 , 2700000, 890000, 23000000, 1100000, 1340000, 1500000],
    'Age' : [22, 23, 24, 23, 25, 24, 26, 28, 29, 27],
    'Company' : ['Google Alphabet', 'Microsot', 'Amazon', 'Nvidia', 'SpaceX', 'OpenAI', 'Mata', 'Samsung', 'Apple', 'Anthropic'],
    'Address' : ['Mountain View, California', 'Redmond, Washington', 'Seattle, Washington', 'Santa Clara, California', 'Hawthorne, California', 'San Francisco, California', 'New York, New York', 'Suwon, South Korea', 'Cupertino, California', 'San Francisco, California'],
    'Experience' : ['1 years', '1.4 years', '2 years', '1.1 years', '2.8 years', '1.5 years', '1.3 years', '3 years', '3.8 years', '2.9 years'],
    'Performance Points' : [67, 78, 98, 87, 81, 85, 88, 89, 97, 93]
}

df = pd.DataFrame(Data)

df
# Out:
#       Name                                Job Type  Salary(Rs)  Age  \
# 0    Ahmad                            Data Analyst      500000   22
# 1    Tariq                          Data Scientist     1730000   23
# 2    Maria               Machine learning Enginear     1240000   24
# 3    Sofia                         Gen AI Engineer     2300000   23
# 4    Zenat  Agentic  AI and Deep learning Engineer     2700000   25
# 5    Rehan                       Software Engineer      890000   24
# 6   Faizan                      AI Product Manager    23000000   26
# 7     Saad                                      HR     1100000   28
# 8  Khadija                       Managing Director     1340000   29
# 9  Sameena                       Marketing Manager     1500000   27
#
#            Company                    Address Experience  Performance Points
# 0  Google Alphabet  Mountain View, California    1 years                  67
# ...

# %%
df.to_csv('Data_sources&Data_sets/Employees_Info_dataset.csv', index=False)

print(df)
# Out:
#       Name                                Job Type  Salary(Rs)  Age  \
# 0    Ahmad                            Data Analyst      500000   22
# 1    Tariq                          Data Scientist     1730000   23
# 2    Maria               Machine learning Enginear     1240000   24
# 3    Sofia                         Gen AI Engineer     2300000   23
# 4    Zenat  Agentic  AI and Deep learning Engineer     2700000   25
# 5    Rehan                       Software Engineer      890000   24
# 6   Faizan                      AI Product Manager    23000000   26
# 7     Saad                                      HR     1100000   28
# 8  Khadija                       Managing Director     1340000   29
# 9  Sameena                       Marketing Manager     1500000   27
#
#            Company                    Address Experience  Performance Points
# 0  Google Alphabet  Mountain View, California    1 years                  67
# ...

# %%
# Now we use Describe() method that shows descriptive Statistics of 'Employees_Info_dataset.csv or any aother particular dataset :

Discriptive_Statistics_info = df.describe()

print(Discriptive_Statistics_info)
# Out:
#          Salary(Rs)        Age  Performance Points
# count  1.000000e+01  10.000000           10.000000
# mean   3.630000e+06  25.100000           86.300000
# std    6.836497e+06   2.330951            9.298148
# min    5.000000e+05  22.000000           67.000000
# 25%    1.135000e+06  23.250000           82.000000
# 50%    1.420000e+06  24.500000           87.500000
# 75%    2.157500e+06  26.750000           92.000000
# max    2.300000e+07  29.000000           98.000000
